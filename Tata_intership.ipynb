# %% [markdown]
# <a href="https://colab.research.google.com/github/MUQSEED961/Credit-Delinquency-Prediction-and-Dashboard/blob/main/Tata_intership.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
delinquency = pd.read_csv("/content/delinquency_dataset_colab_tata.csv")

# %%
delinquency.head()
# Out:
#   Customer_ID   Age    Income  Credit_Score  Credit_Utilization  \
# 0    CUST0001  56.0  165580.0         398.0            0.390502
# 1    CUST0002  69.0  100999.0         493.0            0.312444
# 2    CUST0003  46.0  188416.0         500.0            0.359930
# 3    CUST0004  32.0  101672.0         413.0            0.371400
# 4    CUST0005  60.0   38524.0         487.0            0.234716
#
#    Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0              3.0                 0.0       16310.0              0.317396
# 1              6.0                 1.0       17401.0              0.196093
# 2              0.0                 0.0       13761.0              0.301655
# 3              3.0                 0.0       88778.0              0.264794
# 4              2.0                 0.0       13316.0              0.510583
#
#   Employment_Status  Account_Tenure Credit_Card_Type     Location Month_1  \
# ...

# %%
delinquency.isnull().sum()
# Out:
# Customer_ID              0
# Age                      0
# Income                  39
# Credit_Score             2
# Credit_Utilization       0
# Missed_Payments          0
# Delinquent_Account       0
# Loan_Balance            29
# Debt_to_Income_Ratio     0
# Employment_Status        0
# Account_Tenure           0
# Credit_Card_Type         0
# Location                 0
# Month_1                  0
# Month_2                  0
# Month_3                  0
# Month_4                  0
# Month_5                  0
# Month_6                  0
# dtype: int64

# %%
delinquency['Income']=delinquency['Income'].fillna(delinquency['Income'].median())
delinquency['Credit_Score']=delinquency['Credit_Score'].fillna(delinquency['Credit_Score'].median())

# %%
delinquency['Loan_Balance']=delinquency['Loan_Balance'].fillna(delinquency["Loan_Balance"].median())

# %%
delinquency.dtypes
# Out:
# Customer_ID              object
# Age                     float64
# Income                  float64
# Credit_Score            float64
# Credit_Utilization      float64
# Missed_Payments         float64
# Delinquent_Account      float64
# Loan_Balance            float64
# Debt_to_Income_Ratio    float64
# Employment_Status        object
# Account_Tenure          float64
# Credit_Card_Type         object
# Location                 object
# Month_1                  object
# Month_2                  object
# Month_3                  object
# Month_4                  object
# Month_5                  object
# Month_6                  object
# dtype: object

# %%
x = delinquency.drop(['Customer_ID','Employment_Status','Credit_Card_Type','Delinquent_Account','Location','Month_1','Month_2','Month_3','Month_4','Month_5','Month_6'],axis=1)
y=delinquency['Delinquent_Account']

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scale = StandardScaler()

# %%
X_scale
# Out:
# StandardScaler()

# %%
X_scaled=X_scale.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_trian,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=45,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Logictic Regression

# %%
model=LogisticRegression(class_weight='balanced')

# %%
model
# Out:
# LogisticRegression(class_weight='balanced')

# %%
model.fit(x_trian,y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred_log = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,f1_score,roc_auc_score,accuracy_score

# %%
confusion_matrix(y_test,y_pred_log)
# Out:
# array([[33, 51],
#        [ 9,  7]])

# %%
f1_log=f1_score(y_test,y_pred_log)
f1_log
# Out:
# 0.1891891891891892

# %%
auc_log=roc_auc_score(y_test,y_pred_log)
auc_log
# Out:
# np.float64(0.41517857142857145)

# %%
acc_log = accuracy_score(y_test,y_pred_log)
acc_log
# Out:
# 0.4

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(class_weight='balanced')

# %%
model_rf
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
model_rf.fit(x_trian,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
# Step 1: Get probabilities
y_prob_rf = model.predict_proba(x_test)[:,1]

# Step 2: Apply custom threshold
y_pred_rf = (y_prob_rf > 0.5).astype(int)

# %%
confusion_matrix(y_test,y_pred_rf)
# Out:
# array([[33, 51],
#        [ 9,  7]])

# %%
auc_rf = roc_auc_score(y_test,y_prob_rf)

# %%
auc_rf
# Out:
# np.float64(0.38913690476190477)

# %%
f1_rf=f1_score(y_test,y_pred_rf)
f1_rf
# Out:
# 0.1891891891891892

# %%
acc_rf=accuracy_score(y_test,y_pred_rf)
acc_rf
# Out:
# 0.4

# %% [markdown]
# XGBoost

# %%
from xgboost import XGBClassifier

# %%
model_xgb = XGBClassifier(n_estimators=200,max_depth=5,random_state=45)

# %%
model_xgb
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model_xgb.fit(x_trian,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_prob_xgb = model_xgb.predict_proba(x_test)[:,1]

y_pred_xgb = (y_prob_xgb > 0.1).astype(int)   # start with 0.4 threshold

# %%
auc_xgb=roc_auc_score(y_test,y_prob_xgb)
auc_xgb
# Out:
# np.float64(0.39806547619047616)

# %%
f1_xgb=f1_score(y_test,y_pred_xgb)
f1_xgb
# Out:
# 0.09523809523809523

# %%
acc_xgb=accuracy_score(y_test,y_pred_xgb)
acc_xgb
# Out:
# 0.62

# %%
confusion_matrix(y_test,y_pred_xgb)
# Out:
# array([[60, 24],
#        [14,  2]])

# %% [markdown]
# GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_gbr = GradientBoostingClassifier(n_estimators=200,max_depth=10,random_state=45)

# %%
model_gbr.fit(x_trian,y_train)
# Out:
# GradientBoostingClassifier(max_depth=10, n_estimators=200, random_state=45)

# %%
y_prob_gbc = model_xgb.predict_proba(x_test)[:,1]

y_pred_gbc = (y_prob_gbc > 0.1).astype(int)   # start with 0.4 threshold

# %%
acc_gbc=accuracy_score(y_test,y_pred_gbc)
acc_gbc
# Out:
# 0.62

# %%
confusion_matrix(y_test,y_pred_gbc)
# Out:
# array([[60, 24],
#        [14,  2]])

# %%
f1_gbc=f1_score(y_test,y_pred_gbc)
f1_gbc
# Out:
# 0.09523809523809523

# %%
auc_gbc=roc_auc_score(y_test,y_prob_gbc)
auc_gbc
# Out:
# np.float64(0.39806547619047616)

# %%
metrics_df = pd.DataFrame({
    "Model": ["Logistic", "Random Forest", "XGBoost", "Gradient Boost"],
    "Accuracy": [acc_log, acc_rf, acc_xgb, acc_gbc],
    "F1 Score": [f1_log, f1_rf, f1_xgb, f1_gbc],
    "AUC": [auc_log, auc_rf, auc_xgb, auc_gbc]
})

# %%
metrics_df
# Out:
#             Model  Accuracy  F1 Score       AUC
# 0        Logistic      0.40  0.189189  0.415179
# 1   Random Forest      0.40  0.189189  0.389137
# 2         XGBoost      0.62  0.095238  0.398065
# 3  Gradient Boost      0.62  0.095238  0.398065

# %%
metrics_df.to_csv("model_metrics.csv", index=False)
